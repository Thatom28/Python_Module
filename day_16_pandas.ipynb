# %% [markdown]
# ## Pandas
# - used to analyse 2D or nnull data
# -table like data
# -they use numpy

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Creating data
# - creating data from dictionaries
# - and you can import from csv
#
# final data is a data frame

# %%
import pandas as pd

pd
# Out:
# <module 'pandas' from 'c:\\Users\\E1005292\\OneDrive - Sanlam Life Insurance Limited\\Documents\\Python basics\\Python_Module\\myenv\\lib\\site-packages\\pandas\\__init__.py'>

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 32],
    'City': ['New York', 'Paris', 'Berlin', 'London']
}
data
# Out:
# {'Name': ['John', 'Anna', 'Peter', 'Linda'],
#  'Age': [28, 34, 29, 32],
#  'City': ['New York', 'Paris', 'Berlin', 'London']}

# %% [markdown]
# ## Making a dataframe from the data
# - the 0, 1, 2 are the index of the values.
# - the act as a primary key
# - each column is a series

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   34     Paris
# 2  Peter   29    Berlin
# 3  Linda   32    London

# %% [markdown]
# ## filtering the output
# - note!! it is case sensitive

# %%
type(df)
type(df['Name'])
df['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %% [markdown]
# In sql
# - select name
#   from df

# %% [markdown]
# Filtering rows
# - df.head(number od rows to return)

# %%
df.head(2)
# Out:
#    Name  Age      City
# 0  John   28  New York
# 1  Anna   34     Paris

# %% [markdown]
# ### Info
# - df.info()
# - how many columns you have,
# - their data types
# - null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %% [markdown]
# df.shape
#
# -gives you the columns and rows the dataframe has
#
# df.dtypes
# - gives you the datatype of each column
#
# df.columns
# -gives you the column names

# %%
df.shape
df.dtypes
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %% [markdown]
# df.describe
# - gives information about the integers and floats
# - gives you the mean and the median
# - the average and std, max
# - it does this for the whole table
#
# df.describe(inlude('all'))
# - give s youthe fell of integers plus all other rows

# %%
df.describe()  #only int and float colums
df.describe(include='all') #all the columns
# Out:
#         Name        Age      City
# count      4   4.000000         4
# unique     4        NaN         4
# top     John        NaN  New York
# freq       1        NaN         1
# mean     NaN  30.750000       NaN
# std      NaN   2.753785       NaN
# min      NaN  28.000000       NaN
# 25%      NaN  28.750000       NaN
# 50%      NaN  30.500000       NaN
# 75%      NaN  32.500000       NaN
# max      NaN  34.000000       NaN

# %% [markdown]
# CSV
# - comma separated values
# - comma separates columns

# %% [markdown]
# ## Real world data
# - reading from the csv file

# %%
tips_df = pd.read_csv('tips.csv')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Try to select day, day, tie

# %%
tips_df[['day','time', 'tip']].head(5)
# Out:
#    day    time   tip
# 0  Sun  Dinner  1.01
# 1  Sun  Dinner  1.66
# 2  Sun  Dinner  3.50
# 3  Sun  Dinner  3.31
# 4  Sun  Dinner  3.61

# %% [markdown]
# adding a new column
# tips-def['new_column_name']

# %%
tips_df[['tip', 'size']].head(5)
tips_df['tips_per_person'] = tips_df['tip'] / tips_df['size']
tips_df.head(5)
tips_df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_per_person
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2         1.500000
# 235       10.07  1.25    Male     No   Sat  Dinner     2         0.625000
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2         0.500000
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2         0.585000
# 238       35.83  4.67  Female     No   Sat  Dinner     3         1.556667
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2         1.500000

# %% [markdown]
# ## find the percentage people are tipping
# - add it as another column

# %%
tips_df['tip_percentage'] = ((tips_df['tip'] / tips_df['total_bill']) * 100).round(2)
# tips_df['tip_percentage'] = ((tips_df['tip'] / tips_df['total_bill']) * 100,2)  #sam as above
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0.505000
# 1         10.34  1.66    Male     No   Sun  Dinner     3         0.553333
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1.166667
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1.655000
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0.902500
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2         1.500000
#
#      tip_percentage
# 0              5.94
# 1             16.05
# ...

# %% [markdown]
# ## sorting
# - tips_df.sort_values(by="Column_name", ascending=(true or false))

# %%
tips_df.sort_values(by='total_bill', ascending=False).head(5)
# Out:
#      total_bill    tip   sex smoker  day    time  size  tips_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3         3.333333
# 212       48.33   9.00  Male     No  Sat  Dinner     4         2.250000
# 59        48.27   6.73  Male     No  Sat  Dinner     4         1.682500
# 156       48.17   5.00  Male     No  Sun  Dinner     6         0.833333
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3         1.166667
#
#      tip_percentage
# 170           19.68
# 212           18.62
# 59            13.94
# 156           10.38
# 182            7.72

# %% [markdown]
# ## Filtering
# - e.g find the rows where people went on sunday

# %%
tips_df[tips_df['day'] == "Sun"]

# tips_df[tips_df['day'] == "Sun"].shape[0]  #to get the rows count
# tips_df[tips_df['day'] == "Sun"].shape[1]  #to get the column count
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2         0.505000
# 1         10.34  1.66    Male     No  Sun  Dinner     3         0.553333
# 2         21.01  3.50    Male     No  Sun  Dinner     3         1.166667
# 3         23.68  3.31    Male     No  Sun  Dinner     2         1.655000
# 4         24.59  3.61  Female     No  Sun  Dinner     4         0.902500
# ..          ...   ...     ...    ...  ...     ...   ...              ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3         1.166667
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5         0.400000
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3         1.166667
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3         1.333333
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2         0.750000
#
#      tip_percentage
# 0              5.94
# 1             16.05
# 2             16.66
# ...

# %% [markdown]
# ## task 2
# get rows where people tipped more than 3 on friday
#
# # Values counts
# tips_df = (tips_df['tips] > 3).value_count()
# - counts similar intems
# - count the bool of how many are greater than 3

# %% [markdown]
# .value count
# - groups the simalar items and gives you the count of the values

# %%
tips_df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
friday = tips_df[tips_df['day'] == "Fri"] 
friday[friday['tip'] > 3]

# selct * from tips-df where day = 'sun' and tip > 3
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 91        22.49  3.50    Male     No  Fri  Dinner     2           1.7500
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2           2.1500
# 94        22.75  3.25  Female     No  Fri  Dinner     2           1.6250
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4           1.1825
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2           2.0000
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2           1.7400
#
#      tip_percentage
# 91            15.56
# 93            26.35
# 94            14.29
# 95            11.77
# 96            14.66
# 221           25.93

# %% [markdown]
# ## task 3 :
# Extend task 2 , top 5 tips on friday

# %%
friday_tips = tips_df[tips_df['day'] == "Fri"] 
friday_tips[friday_tips['tip'] > 3].sort_values(by='tip', ascending = False).head(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4           1.1825
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2           2.1500
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2           2.0000
# 91        22.49  3.50    Male     No  Fri  Dinner     2           1.7500
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2           1.7400
#
#      tip_percentage
# 95            11.77
# 93            26.35
# 96            14.66
# 91            15.56
# 221           25.93

# %% [markdown]
# ## task 4
# large parties: if people are 5 or more or spend money more than 35
# -Using or(|) and and(&)

# %%
tips_df[(tips_df['size'] >= 5) | (tips_df['total_bill'] >= 35)].sort_values(by='size')
# Out:
#      total_bill    tip     sex smoker   day    time  size  tips_per_person  \
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2         1.500000
# 238       35.83   4.67  Female     No   Sat  Dinner     3         1.556667
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3         0.833333
# 112       38.07   4.00    Male     No   Sun  Dinner     3         1.333333
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3         1.166667
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3         3.333333
# 212       48.33   9.00    Male     No   Sat  Dinner     4         2.250000
# 207       38.73   3.00    Male    Yes   Sat  Dinner     4         0.750000
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4         1.250000
# 11        35.26   5.00  Female     No   Sun  Dinner     4         1.250000
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4         1.182500
# ...

# %%
#dot syntax and box syntax
tips_df.smoker
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %% [markdown]
# Data exploration
# -giving valuable data to the company and meaningful data
# - this might derive solutions

# %% [markdown]
# ## summary
# - filter rows and columns
# - how to get limit using the head and Tail
# - orderby using sort_values(by='')
# - conditional with operation

# %% [markdown]
# ## slicing in Pandas
# - loc : match the value in the table not the row position (inclusive)
# - iloc - based on the data, it matches the location of the value in the table(row position)(exclusive)

# %%
tips_df.head(6)
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2         0.505000
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0.553333
# 2       21.01  3.50    Male     No  Sun  Dinner     3         1.166667
# 3       23.68  3.31    Male     No  Sun  Dinner     2         1.655000
# 4       24.59  3.61  Female     No  Sun  Dinner     4         0.902500
# 5       25.29  4.71    Male     No  Sun  Dinner     4         1.177500
#
#    tip_percentage
# 0            5.94
# 1           16.05
# 2           16.66
# 3           13.98
# 4           14.68
# 5           18.62

# %%
tips_df.iloc[3]  #returns the index specified
tips_df.iloc[3:5] #returns the 3rd and the 4th row
tips_df.iloc[3:5, 2:5]  #the values of the columns
# Out:
#       sex smoker  day
# 3    Male     No  Sun
# 4  Female     No  Sun

# %% [markdown]
# ## loc
# -locates the indexes/name specified

# %%
tips_df.loc[3]  #returns the index specified
tips_df.loc[3:5] #returns the 3rd and the 4th row and 5th 
tips_df.loc[3:5, 'tip'] #filter the columns, only return the tip column
tips_df.loc[3:5, 'tip' : 'day']  #returns the range of columns
# Out:
#     tip     sex smoker  day
# 3  3.31    Male     No  Sun
# 4  3.61  Female     No  Sun
# 5  4.71    Male     No  Sun

# %%
tips_df.tail(10).loc[235: 239]
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 235       10.07  1.25    Male     No  Sat  Dinner     2         0.625000
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2         0.500000
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2         0.585000
# 238       35.83  4.67  Female     No  Sat  Dinner     3         1.556667
# 239       29.03  5.92    Male     No  Sat  Dinner     3         1.973333
#
#      tip_percentage
# 235           12.41
# 236            7.94
# 237            3.56
# 238           13.03
# 239           20.39

# %% [markdown]
# ## task 1
# - find the  rows with the highest tip_percentage and skip the fist 5 in the result on a weekend

# %%
# high_tips_on_weekends = tips_df[(tips_df['day'] == 'Sat') | (tips_df['day'] == 'Sun')].sort_values(by='tip', ascending=False).iloc[5:]
high_tips_on_weekends = tips_df[(tips_df['day'] == 'Sat') | (tips_df['day'] == 'Sun')].sort_values(by='tip', ascending=False)
high_tips_on_weekends
# Out:
#      total_bill    tip     sex smoker  day    time  size  tips_per_person  \
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3         3.333333
# 212       48.33   9.00    Male     No  Sat  Dinner     4         2.250000
# 23        39.42   7.58    Male     No  Sat  Dinner     4         1.895000
# 59        48.27   6.73    Male     No  Sat  Dinner     4         1.682500
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3         2.166667
# ..          ...    ...     ...    ...  ...     ...   ...              ...
# 215       12.90   1.10  Female    Yes  Sat  Dinner     2         0.550000
# 0         16.99   1.01  Female     No  Sun  Dinner     2         0.505000
# 67         3.07   1.00  Female    Yes  Sat  Dinner     1         1.000000
# 236       12.60   1.00    Male    Yes  Sat  Dinner     2         0.500000
# 111        7.25   1.00  Female     No  Sat  Dinner     1         1.000000
#
#      tip_percentage
# 170           19.68
# 212           18.62
# ...

# %% [markdown]
# ## task 2
# final results should include only tip_percentage, tip, total_bill

# %%
high_tips_on_weekends.iloc[5:,[0,1,4,8]]
#or
# high_tips_on_weekends.iloc[5:,['total_bill','tip','day','tip_percentage']]
# Out:
#      total_bill   tip  day  tip_percentage
# 183       23.17  6.50  Sun           28.05
# 47        32.40  6.00  Sun           18.52
# 239       29.03  5.92  Sat           20.39
# 181       23.33  5.65  Sun           24.22
# 44        30.40  5.60  Sun           18.42
# ..          ...   ...  ...             ...
# 215       12.90  1.10  Sat            8.53
# 0         16.99  1.01  Sun            5.94
# 67         3.07  1.00  Sat           32.57
# 236       12.60  1.00  Sat            7.94
# 111        7.25  1.00  Sat           13.79
#
# [158 rows x 4 columns]

# %% [markdown]
# ##task 3
# filter the rows fron the last 6 rows

# %%
tips_df.tail(6).loc[:,'tip':'day'].iloc[2:4]
# Out:
#      tip     sex smoker  day
# 240  2.0  Female    Yes  Sat
# 241  2.0    Male    Yes  Sat

# %% [markdown]
# # statistics
# - mean
# - median
# - sum

# %%
tips_df['tip'].mean()
tips_df['tip'].median()
tips_df['tip'].sum()

# mean on multiple columns

tips_df[['total_bill', 'tip']].mean()
tips_df[['total_bill', 'tip']].median()
tips_df[['total_bill', 'tip']].mode()
tips_df[['total_bill', 'tip']].sum()
# Out:
# total_bill    4827.77
# tip            731.58
# dtype: float64

# %% [markdown]
# ## task 1
# - average total bill in anyday
# select *, avg(total_bill)
# from tips_df
# group_by day
# ## groupby
# - needs the group by column
# - the column to use the aggregation on
# - what aggregation are you using

# %%
tips_df.groupby("day").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\E1005292\OneDrive - Sanlam Life Insurance Limited\Documents\Python basics\Python_Module\myenv\lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\E1005292\OneDrive - Sanlam Life Insurance Limited\Documents\Python basics\Python_Module\myenv\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...

# %%
# Who leaves more tip, and smoker and non-smoker 
tips_df.groupby("smoker")['tip'].sum()

# On average who leaves more tips
tips_df.groupby("smoker")['tip'].mean()

# combine the two functions
tips_df.groupby("smoker").aggregate({'tip':'sum', 'total_bill': 'mean'})
tips_df.groupby("smoker").aggregate({'tip':['sum', 'mean'], 'total_bill': 'mean'})  #if you need to applay sum and mean in one column
# Out:
#            tip           total_bill
#            sum      mean       mean
# smoker
# No      451.77  2.991854  19.188278
# Yes     279.81  3.008710  20.756344

# %% [markdown]
# ## Task:
# - Based on the day calculate total of total_bill and on average what is tip_percent

# %%
tips_df.groupby('day').aggregate({'total_bill': 'sum', 'tip_percentage': 'mean'})
# Out:
#       total_bill  tip_percentage
# day
# Fri       325.88       16.991579
# Sat      1778.40       15.314598
# Sun      1627.16       16.689605
# Thur     1096.33       16.126452

# %% [markdown]
# ## one more level of drilling
# -we want to see how much they each tip per day
# - group smokers and day.
# - who gives tips more on each day

# %%
tips_df.groupby(['smoker', 'day'])['tip'].mean()
# Out:
# smoker  day
# No      Fri     2.812500
#         Sat     3.102889
#         Sun     3.167895
#         Thur    2.673778
# Yes     Fri     2.714000
#         Sat     2.875476
#         Sun     3.516842
#         Thur    3.030000
# Name: tip, dtype: float64

# %% [markdown]
# ## task
# - on average who(male or female) earns more tips each day

# %%
tips_df.groupby(['sex', 'day'])['tip'].mean()
tips_df.groupby(['day', 'sex'])['tip'].mean()
# Out:
# day   sex
# Fri   Female    2.781111
#       Male      2.693000
# Sat   Female    2.801786
#       Male      3.083898
# Sun   Female    3.367222
#       Male      3.220345
# Thur  Female    2.575625
#       Male      2.980333
# Name: tip, dtype: float64

# %% [markdown]
# ## unstack
# transforms the results, therefore it is easier to analyze  (pull out the aggregate columns in to a separate columns)

# %%
# Modified the above with stack
tips_df.groupby(['sex', 'day'])['tip'].mean().unstack()
# Out:
# day          Fri       Sat       Sun      Thur
# sex
# Female  2.781111  2.801786  3.367222  2.575625
# Male    2.693000  3.083898  3.220345  2.980333

# %% [markdown]
# ## Task
# - on average, max, min who(male or female) earns more tips each day

# %%
tips_df.groupby(['sex', 'day']).aggregate({'tip': ['mean', 'max', 'min']})
tips_df.groupby(['day', 'sex']).aggregate({'tip': ['min', 'mean', 'max']}).unstack()
# Out:
#         tip
#         min            mean              max
# sex  Female  Male    Female      Male Female   Male
# day
# Fri    1.00  1.50  2.781111  2.693000   4.30   4.73
# Sat    1.00  1.00  2.801786  3.083898   6.50  10.00
# Sun    1.01  1.32  3.367222  3.220345   5.20   6.50
# Thur   1.25  1.44  2.575625  2.980333   5.17   6.70

# %% [markdown]
# ## Pivot tables

# %%
pd.pivot_table(tips_df,index='day', columns='smoker', values='tip', aggfunc='sum')
# Out:
# smoker      No     Yes
# day
# Fri      11.25   40.71
# Sat     139.63  120.77
# Sun     180.57   66.82
# Thur    120.32   51.51

# %% [markdown]
# ## visualize
# - matplot
#     - beginner friendly
#     - pioneer
# - seaborn
#     - it uses matplot internally
#     - complex visualization easily
